# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Escenario 1

# %% [markdown]
# El concepto de interacción es posible representarlo

# %%
def f(x1,x2):
    return 35.5 + 10.5*x1 + 10.5*x2 + 12.5*x1*x2

x = np.linspace(-1,1,100)
p = np.linspace(-1,1,100)

X,P = np.meshgrid(x,p)
y = f(X,P)

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection='3d')

ax.plot_surface(X, P, y, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none');

# %%
cs = plt.contour(X,P,y,15)
plt.clabel(cs, inline=1, fontsize=8)

plt.show()

# %% [markdown]
# ## Escenario 2

# %%
def f(x1,x2):
    return 30.5 + 0.5*x1 + 1.5*x2 + 48*x1*x2

x = np.linspace(-1,1,100)
p = np.linspace(-1,1,100)

X,P = np.meshgrid(x,p)
y = f(X,P)

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection='3d')

ax.plot_surface(X, P, y, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none');

# %%
cs = plt.contour(X,P,y,15)
plt.clabel(cs, inline=1, fontsize=8)

plt.show()
